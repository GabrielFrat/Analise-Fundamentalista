# %%
import fundamentus as fd
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# 2023-10-31 10:54:23,648 [logging.log_init] INFO: LOGLEVEL=INFO

# %%
df =  fd.get_resultado()
df.to_excel(r'C:\Users\gabri\OneDrive - XP Investimentos\Settima - BI\Python Scripts\7. Análise de Dados\Analise Fundamentalista\Analises.xlsx')
print(df)
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa     pcg   pebit   pacl  \
# papel
# AALR3         9.48   -3.91  1.30  0.990  0.0000  0.445   -3.48 -661.99  -0.90
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000    0.00    0.00   0.00
# ABCB4        19.21    5.38  0.80  0.000  0.0628  0.000    0.00    0.00   0.00
# ABEV3        12.44   13.73  2.30  2.369  0.0613  1.470  968.57   12.03 -15.55
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527    1.98   19.96  -2.75
# ...            ...     ...   ...    ...     ...    ...     ...     ...    ...
# WLMM4        37.50   12.04  2.09  0.616  0.0255  1.446    3.93   10.21   4.67
# WMBY3        25.39  -19.30  2.87  0.836  0.0000  0.182    1.20    8.62  -1.50
# WSON33       67.00    8.07  0.98  1.067  0.0000  0.400   13.41    2.42  -0.89
# YDUQ3        18.29   51.31  1.80  1.164  0.0150  0.581    6.13    7.55  -1.42
# ZAMP3         6.24  -15.42  1.26  0.455  0.0000  0.428   12.89   20.21  -0.97
#
# ...

# %%
df.loc['VALE3']
# Out:
# Multiples
# cotacao     6.393000e+01
# pl          5.100000e+00
# pvp         1.550000e+00
# psr         1.406000e+00
# dy          6.340000e-02
# pa          6.580000e-01
# pcg         3.025000e+01
# pebit       3.720000e+00
# pacl       -1.690000e+00
# evebit      4.270000e+00
# evebitda    3.540000e+00
# mrgebit     3.778000e-01
# mrgliq      2.780000e-01
# roic        1.992000e-01
# roe         3.045000e-01
# liqc        1.150000e+00
# liq2m       1.611350e+09
# patrliq     1.869880e+11
# divbpatr    3.600000e-01
# c5y         1.303000e-01
# Name: VALE3, dtype: float64

# %%
setor = ['PETR4', 'PRIO3']
df.query('index in @setor')
# Out:
# Multiples  cotacao     pl   pvp    psr      dy     pa     pcg  pebit  pacl  \
# papel
# PETR4        36.07   3.01  1.27  0.809  0.2565  0.475  -31.83   1.80 -0.98
# PRIO3        48.36  11.53  3.99  5.306  0.0000  1.651 -106.37   9.26 -3.71
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# PETR4        2.63      2.05   0.4497  0.2699  0.2895  0.4219   0.9
# PRIO3       11.23      8.74   0.5728  0.4603  0.1923  0.3461   0.9
#
# Multiples         liq2m       patrliq  divbpatr     c5y
# papel
# PETR4      1.741070e+09  3.706830e+11      0.75  0.1942
# PRIO3      4.270410e+08  1.075390e+10      0.95  0.6923

# %%
filtro = df[(df.pl > 15) & (df.dy > 0.05)]

# %%
filtro.shape
# Out:
# (16, 20)

# %%
plt.figure(figsize = (14, 16))
df.sort_values('mrgebit', inplace = True)
plt.bar(df.index, df.mrgebit)
# Out:
# <BarContainer object of 967 artists>

# %%
plt.figure(figsize = (14, 16))
filtro.sort_values('mrgebit', inplace = True)
plt.bar(filtro.index, filtro.mrgebit)
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_13228\3718070453.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro.sort_values('mrgebit', inplace = True)
# <BarContainer object of 16 artists>

# %%
filtro2 = df[(df.pl < 10) & (df.dy > 0.04) & (df.roe > 0.1) & (df.mrgliq > 0.08) & (df.c5y > 0) & (df.liq2m > 250000)]
filtro2.shape
# Out:
# (46, 20)

# %%
filtro2.sort_values('dy', ascending=False)
# Out:
# Multiples  cotacao    pl   pvp     psr      dy     pa    pcg  pebit   pacl  \
# papel
# PETR4        36.07  3.01  1.27   0.809  0.2565  0.475 -31.83   1.80  -0.98
# PETR3        39.05  3.26  1.37   0.876  0.2369  0.514 -34.46   1.95  -1.06
# GRND3         6.17  9.99  1.65   2.262  0.2322  1.501   2.83  16.88   2.88
# GGBR3        19.95  3.67  0.72   0.460  0.1621  0.475   1.75   2.85   6.17
# GGBR4        21.47  3.95  0.77   0.495  0.1507  0.511   1.89   3.07   6.64
# AGRO3        24.54  9.38  1.15   1.969  0.1316  0.718   3.51   8.78  65.34
# GOAU3        10.02  3.24  0.60   0.136  0.1158  0.138   0.49   0.84   1.55
# GOAU4        10.07  3.25  0.60   0.137  0.1152  0.139   0.50   0.85   1.56
# AURE3        13.32  4.30  0.90   2.267  0.1126  0.404   2.74  15.97  -1.47
# KEPL3        10.39  5.96  2.79   1.151  0.1095  1.530   4.99   4.88   8.28
# LEVE3        40.46  7.35  3.64   1.165  0.1077  1.725   5.69   6.18  16.74
# ...

# %%
plt.figure(figsize = (18, 8))
plt.bar(filtro2.index, filtro2.dy)
plt.xticks(rotation=45)
plt.title("Análise Fundamentalista /PL - DY - ROE - Mrg Liq - c5y - liq2m/")
# Out:
# Text(0.5, 1.0, 'Análise Fundamentalista /PL - DY - ROE - Mrg Liq - c5y - liq2m/')

# %%
dfAtivos = filtro2.reset_index()
dfAtivos = dfAtivos.sort_values(by='dy', ascending=False)
dfAtivos = dfAtivos.reset_index()
dfAtivos = dfAtivos.reset_index()
dfAtivos = dfAtivos.rename(columns={'level_0': 'Pts dy'})
dfAtivos.drop
print(dfAtivos)
# Out:
# Multiples  Pts dy  index   papel  cotacao    pl   pvp     psr      dy     pa  \
# 0               0     42   PETR4    36.07  3.01  1.27   0.809  0.2565  0.475
# 1               1     41   PETR3    39.05  3.26  1.37   0.876  0.2369  0.514
# 2               2      4   GRND3     6.17  9.99  1.65   2.262  0.2322  1.501
# 3               3     12   GGBR3    19.95  3.67  0.72   0.460  0.1621  0.475
# 4               4     13   GGBR4    21.47  3.95  0.77   0.495  0.1507  0.511
# 5               5     24   AGRO3    24.54  9.38  1.15   1.969  0.1316  0.718
# 6               6     11   GOAU3    10.02  3.24  0.60   0.136  0.1158  0.138
# 7               7     10   GOAU4    10.07  3.25  0.60   0.137  0.1152  0.139
# 8               8      7   AURE3    13.32  4.30  0.90   2.267  0.1126  0.404
# 9               9     26   KEPL3    10.39  5.96  2.79   1.151  0.1095  1.530
# 10             10     17   LEVE3    40.46  7.35  3.64   1.165  0.1077  1.725
# ...

# %%
# Criar pontuador para as melhores empresas
dfAtivos = dfAtivos.drop(columns=['index'])

dfAtivos = dfAtivos.sort_values(by='roe', ascending=False)
dfAtivos = dfAtivos.reset_index()

dfAtivos = dfAtivos.drop(columns=['index'])
dfAtivos = dfAtivos.reset_index()
dfAtivos = dfAtivos.rename(columns={'index': 'Pts roe'})
dfAtivos
# Out:
# Multiples  Pts roe  Pts dy   papel  cotacao    pl   pvp     psr      dy  \
# 0                0      10   LEVE3    40.46  7.35  3.64   1.165  0.1077
# 1                1       9   KEPL3    10.39  5.96  2.79   1.151  0.1095
# 2                2       0   PETR4    36.07  3.01  1.27   0.809  0.2565
# 3                3       1   PETR3    39.05  3.26  1.37   0.876  0.2369
# 4                4      26   RANI3    11.20  5.60  2.15   1.671  0.0788
# 5                5      41   JALL3     8.35  4.08  1.28   1.482  0.0515
# 6                6      20   CPFE3    32.82  6.84  2.12   0.946  0.0879
# 7                7      37   VALE3    63.93  5.10  1.55   1.406  0.0634
# 8                8      14   UNIP6    72.07  9.56  2.87   1.195  0.0958
# 9                9      15   UNIP3    67.18  8.91  2.67   1.114  0.0934
# 10              10      18   TASA4    15.38  6.31  1.84   0.901  0.0907
# 11              11      36   VULC3    18.16  8.35  2.36   1.656  0.0636
# ...

# %%
dfAtivos = dfAtivos.sort_values(by='pl', ascending=False)
dfAtivos = dfAtivos.reset_index()

dfAtivos = dfAtivos.drop(columns=['index'])
dfAtivos = dfAtivos.reset_index()
dfAtivos = dfAtivos.rename(columns={'index': 'Pts pl'})
dfAtivos
# Out:
# Multiples  Pts pl  Pts roe  Pts dy   papel  cotacao    pl   pvp     psr  \
# 0               0       35       2   GRND3     6.17  9.99  1.65   2.262
# 1               1       31      13  TAEE11    33.81  9.97  1.74   4.968
# 2               2       30      12   TAEE3    11.24  9.95  1.74   4.955
# 3               3        8      14   UNIP6    72.07  9.56  2.87   1.195
# 4               4       43       5   AGRO3    24.54  9.38  1.15   1.969
# 5               5       32      28   SLCE3    36.92  9.08  1.58   0.939
# 6               6        9      15   UNIP3    67.18  8.91  2.67   1.114
# 7               7       42      45   LAVV3     6.79  8.75  1.10   1.885
# 8               8       19      33   TGMA3    24.32  8.71  2.00   1.051
# 9               9       14      40   KLBN3     4.45  8.68  2.24   1.344
# 10             10       16      38  KLBN11    22.15  8.64  2.23   1.338
# 11             11       15      39   KLBN4     4.43  8.64  2.23   1.338
# ...

# %%
dfAtivos = dfAtivos.sort_values(by='mrgliq', ascending=False)
dfAtivos = dfAtivos.reset_index()

dfAtivos = dfAtivos.drop(columns=['index'])
dfAtivos = dfAtivos.reset_index()
dfAtivos = dfAtivos.rename(columns={'index': 'Pts Mrg Liq'})
dfAtivos
# Out:
# Multiples  Pts Mrg Liq  Pts pl  Pts roe  Pts dy   papel  cotacao    pl   pvp  \
# 0                    0      19       33      23   ITSA3     8.87  6.48  1.12
# 1                    1      20       34      21   ITSA4     8.71  6.37  1.10
# 2                    2      37       23       8   AURE3    13.32  4.30  0.90
# 3                    3       2       30      12   TAEE3    11.24  9.95  1.74
# 4                    4       1       31      13  TAEE11    33.81  9.97  1.74
# 5                    5      24       41      44   TRPL4    22.22  6.18  0.84
# 6                    6      38        5      41   JALL3     8.35  4.08  1.28
# 7                    7      22       18      42   RECV3    21.35  6.28  1.45
# 8                    8      27        4      26   RANI3    11.20  5.60  2.15
# 9                    9      29        7      37   VALE3    63.93  5.10  1.55
# 10                  10      45        2       0   PETR4    36.07  3.01  1.27
# ...

# %%
dfAtivos = dfAtivos.sort_values(by='c5y', ascending=False)
dfAtivos = dfAtivos.reset_index()

dfAtivos = dfAtivos.drop(columns=['index'])
dfAtivos = dfAtivos.reset_index()
dfAtivos = dfAtivos.rename(columns={'index': 'Pts c5y'})
dfAtivos
# Out:
# Multiples  Pts c5y  Pts Mrg Liq  Pts pl  Pts roe  Pts dy   papel  cotacao  \
# 0                0            7      22       18      42   RECV3    21.35
# 1                1            2      37       23       8   AURE3    13.32
# 2                2           40       5       32      28   SLCE3    36.92
# 3                3           20      25        1       9   KEPL3    10.39
# 4                4           18       4       43       5   AGRO3    24.54
# 5                5           31      21       10      18   TASA4    15.38
# 6                6           12      23       22      31   FESA4    48.17
# 7                7           37       3        8      14   UNIP6    72.07
# 8                8           38       6        9      15   UNIP3    67.18
# 9                9           19      12       11      36   VULC3    18.16
# 10              10           36      39       26       4   GGBR4    21.47
# 11              11           35      41       25       3   GGBR3    19.95
# ...

# %%
dfAtivos = dfAtivos.sort_values(by='liq2m', ascending=False)
dfAtivos = dfAtivos.reset_index()

dfAtivos = dfAtivos.drop(columns=['index'])
dfAtivos = dfAtivos.reset_index()
dfAtivos = dfAtivos.rename(columns={'index': 'Pts liq2m'})
dfAtivos
# Out:
# Multiples  Pts liq2m  Pts c5y  Pts Mrg Liq  Pts pl  Pts roe  Pts dy   papel  \
# 0                  0       15           10      45        2       0   PETR4
# 1                  1       28            9      29        7      37   VALE3
# 2                  2       16           11      42        3       1   PETR3
# 3                  3       10           36      39       26       4   GGBR4
# 4                  4       25            1      20       34      21   ITSA4
# 5                  5       31           25      40       13      16   CMIG4
# 6                  6       21           23      10       16      38  KLBN11
# 7                  7       12           34      43       27       7   GOAU4
# 8                  8       29            5      24       41      44   TRPL4
# 9                  9       34            4       1       31      13  TAEE11
# 10                10        0            7      22       18      42   RECV3
# ...

# %%
dfAtivos['Pontução'] = dfAtivos['Pts pl'] + dfAtivos['Pts roe'] + dfAtivos['Pts dy'] + dfAtivos['Pts c5y'] + dfAtivos['Pts Mrg Liq'] + dfAtivos['Pts liq2m']
dfAtivos
# Out:
# Multiples  Pts liq2m  Pts c5y  Pts Mrg Liq  Pts pl  Pts roe  Pts dy   papel  \
# 0                  0       15           10      45        2       0   PETR4
# 1                  1       28            9      29        7      37   VALE3
# 2                  2       16           11      42        3       1   PETR3
# 3                  3       10           36      39       26       4   GGBR4
# 4                  4       25            1      20       34      21   ITSA4
# 5                  5       31           25      40       13      16   CMIG4
# 6                  6       21           23      10       16      38  KLBN11
# 7                  7       12           34      43       27       7   GOAU4
# 8                  8       29            5      24       41      44   TRPL4
# 9                  9       34            4       1       31      13  TAEE11
# 10                10        0            7      22       18      42   RECV3
# ...

# %%
dfAtivos = dfAtivos.sort_values(by='Pontução', ascending=True)
dfAtivos
# Out:
# Multiples  Pts liq2m  Pts c5y  Pts Mrg Liq  Pts pl  Pts roe  Pts dy   papel  \
# 0                  0       15           10      45        2       0   PETR4
# 2                  2       16           11      42        3       1   PETR3
# 22                22        3           20      25        1       9   KEPL3
# 12                12        1            2      37       23       8   AURE3
# 21                21        7           37       3        8      14   UNIP6
# 9                  9       34            4       1       31      13  TAEE11
# 19                19        4           18       4       43       5   AGRO3
# 20                20       22           28      16        0      10   LEVE3
# 10                10        0            7      22       18      42   RECV3
# 4                  4       25            1      20       34      21   ITSA4
# 24                24       18            8      27        4      26   RANI3
# ...

# %%
plt.figure(figsize = (22, 10))
x_labels = dfAtivos['Pontução'].tolist()

plt.bar(dfAtivos.papel, dfAtivos.Pontução)
plt.xticks(rotation=45)

plt.title("Lista de Pontução Acumulada")
# Out:
# Text(0.5, 1.0, 'Lista de Pontução Acumulada')
